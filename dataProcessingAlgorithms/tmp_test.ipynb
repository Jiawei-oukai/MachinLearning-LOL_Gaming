# %%
import GenerateInputDataForMLModel
import pandas as pd

# %%
Lineups = [
    [517,421,18,96,117,145,142,888,5,80],
    [31,1,236,3,136,50,89,53,115,44],
    [2,56,246,429,888,10,141,38,67,350]
    ]

# %%
df_cf = GenerateInputDataForMLModel.to_modelpredictData_comparisonFeature(Lineups,"pre")
df_cf
# Out:
#    Top_counterScore  Jug_counterScore  Mid_counterScore  Bot_counterScore  \
# 0             0.000          0.000000          0.000000          0.000000
# 1             0.000          0.000000          0.000000          0.000000
# 2          -198.375        288.571429      -2048.571429      -1607.291667
#
#    Uti_counterScore  diff_TeamAttackScore  diff_TeamDefenseScore  \
# 0          0.000000                20.630                 14.454
# 1          0.000000               114.822                 30.852
# 2       -408.082474                70.996                 69.144
#
#    diff_TeamWinRate  diff_TeamComboCount  diff_TeamControlScore  \
# 0            19.492                 -1.0               -0.08994
# 1            -4.740                  0.0               -0.08890
# 2             3.850                  0.0                1.12538
#
#    diff_TeamGoldAbility  Team1_AttackDefenseBalanceScore  \
# 0               13.3161                         -138.596
# ...

# %%
df_af = GenerateInputDataForMLModel.to_modelpredictData_allFeature(Lineups,"pre")
df_af.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 57 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Top_counterScore        3 non-null      float64
#  1   Jug_counterScore        3 non-null      float64
#  2   Mid_counterScore        3 non-null      float64
#  3   Bot_counterScore        3 non-null      float64
#  4   Uti_counterScore        3 non-null      float64
#  5   Team1_Top_attackScore   3 non-null      float64
#  6   Team1_Jug_attackScore   3 non-null      float64
#  7   Team1_Mid_attackScore   3 non-null      float64
#  8   Team1_Bot_attackScore   3 non-null      float64
#  9   Team1_Uti_attackScore   3 non-null      float64
#  10  Team2_Top_attackScore   3 non-null      float64
#  11  Team2_Jug_attackScore   3 non-null      float64
#  12  Team2_Mid_attackScore   3 non-null      float64
#  13  Team2_Bot_attackScore   3 non-null      float64
# ...
