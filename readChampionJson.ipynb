# %%
import pandas as pd
from tqdm import tqdm
import os
import json
from glom import glom

# %%
df = pd.read_json('./data_backups/champion.json')

# %%
df= df.T
df
# Out:
#          version       id  key     name                   title  \
# Aatrox   12.12.1   Aatrox  266   Aatrox        the Darkin Blade
# Ahri     12.12.1     Ahri  103     Ahri     the Nine-Tailed Fox
# Akali    12.12.1    Akali   84    Akali      the Rogue Assassin
# Akshan   12.12.1   Akshan  166   Akshan      the Rogue Sentinel
# Alistar  12.12.1  Alistar   12  Alistar            the Minotaur
# ...          ...      ...  ...      ...                     ...
# Zeri     12.12.1     Zeri  221     Zeri       The Spark of Zaun
# Ziggs    12.12.1    Ziggs  115    Ziggs  the Hexplosives Expert
# Zilean   12.12.1   Zilean   26   Zilean        the Chronokeeper
# Zoe      12.12.1      Zoe  142      Zoe  the Aspect of Twilight
# Zyra     12.12.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                      blurb  \
# Aatrox   Once honored defenders of Shurima against the ...
# Ahri     Innately connected to the latent power of Rune...
# Akali    Abandoning the Kinkou Order and her title of t...
# Akshan   Raising an eyebrow in the face of danger, Aksh...
# Alistar  Always a mighty warrior with a fearsome reputa...
# ...                                                    ...
# Zeri     A headstrong, spirited young woman from Zaun's...
# Ziggs    With a love of big bombs and short fuses, the ...
# Zilean   Once a powerful Icathian mage, Zilean became o...
# Zoe      As the embodiment of mischief, imagination, an...
# Zyra     Born in an ancient, sorcerous catastrophe, Zyr...
#
#                                                       info  \
# Aatrox   {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# Ahri     {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# Akali    {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# Akshan   {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# Alistar  {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
# ...                                                    ...
# Zeri     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# Ziggs    {'attack': 2, 'defense': 4, 'magic': 9, 'diffi...
# Zilean   {'attack': 2, 'defense': 5, 'magic': 8, 'diffi...
# Zoe      {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
# Zyra     {'attack': 4, 'defense': 3, 'magic': 8, 'diffi...
#
#                                                      image  \
# Aatrox   {'full': 'Aatrox.png', 'sprite': 'champion0.pn...
# Ahri     {'full': 'Ahri.png', 'sprite': 'champion0.png'...
# Akali    {'full': 'Akali.png', 'sprite': 'champion0.png...
# Akshan   {'full': 'Akshan.png', 'sprite': 'champion0.pn...
# Alistar  {'full': 'Alistar.png', 'sprite': 'champion0.p...
# ...                                                    ...
# Zeri     {'full': 'Zeri.png', 'sprite': 'champion5.png'...
# Ziggs    {'full': 'Ziggs.png', 'sprite': 'champion5.png...
# Zilean   {'full': 'Zilean.png', 'sprite': 'champion5.pn...
# Zoe      {'full': 'Zoe.png', 'sprite': 'champion5.png',...
# Zyra     {'full': 'Zyra.png', 'sprite': 'champion5.png'...
#
#                          tags     partype  \
# Aatrox        [Fighter, Tank]  Blood Well
# Ahri         [Mage, Assassin]        Mana
# Akali              [Assassin]      Energy
# Akshan   [Marksman, Assassin]        Mana
# Alistar       [Tank, Support]        Mana
# ...                       ...         ...
# Zeri               [Marksman]        Mana
# Ziggs                  [Mage]        Mana
# Zilean        [Support, Mage]        Mana
# Zoe           [Mage, Support]        Mana
# Zyra          [Mage, Support]        Mana
#
#                                                      stats
# Aatrox   {'hp': 650, 'hpperlevel': 104, 'mp': 0, 'mpper...
# Ahri     {'hp': 570, 'hpperlevel': 96, 'mp': 418, 'mppe...
# Akali    {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpp...
# Akshan   {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
# Alistar  {'hp': 670, 'hpperlevel': 120, 'mp': 350, 'mpp...
# ...                                                    ...
# Zeri     {'hp': 600, 'hpperlevel': 109, 'mp': 250, 'mpp...
# Ziggs    {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
# Zilean   {'hp': 574, 'hpperlevel': 96, 'mp': 452, 'mppe...
# Zoe      {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...
# Zyra     {'hp': 574, 'hpperlevel': 93, 'mp': 418, 'mppe...
#
# [160 rows x 11 columns]

# %%
df['key'] = pd.to_numeric(df['key'], errors='ignore')
df
# Out:
#          version       id  key     name                   title  \
# Aatrox   12.12.1   Aatrox  266   Aatrox        the Darkin Blade
# Ahri     12.12.1     Ahri  103     Ahri     the Nine-Tailed Fox
# Akali    12.12.1    Akali   84    Akali      the Rogue Assassin
# Akshan   12.12.1   Akshan  166   Akshan      the Rogue Sentinel
# Alistar  12.12.1  Alistar   12  Alistar            the Minotaur
# ...          ...      ...  ...      ...                     ...
# Zeri     12.12.1     Zeri  221     Zeri       The Spark of Zaun
# Ziggs    12.12.1    Ziggs  115    Ziggs  the Hexplosives Expert
# Zilean   12.12.1   Zilean   26   Zilean        the Chronokeeper
# Zoe      12.12.1      Zoe  142      Zoe  the Aspect of Twilight
# Zyra     12.12.1     Zyra  143     Zyra      Rise of the Thorns
#
#                                                      blurb  \
# Aatrox   Once honored defenders of Shurima against the ...
# Ahri     Innately connected to the latent power of Rune...
# Akali    Abandoning the Kinkou Order and her title of t...
# Akshan   Raising an eyebrow in the face of danger, Aksh...
# Alistar  Always a mighty warrior with a fearsome reputa...
# ...                                                    ...
# Zeri     A headstrong, spirited young woman from Zaun's...
# Ziggs    With a love of big bombs and short fuses, the ...
# Zilean   Once a powerful Icathian mage, Zilean became o...
# Zoe      As the embodiment of mischief, imagination, an...
# Zyra     Born in an ancient, sorcerous catastrophe, Zyr...
#
#                                                       info  \
# Aatrox   {'attack': 8, 'defense': 4, 'magic': 3, 'diffi...
# Ahri     {'attack': 3, 'defense': 4, 'magic': 8, 'diffi...
# Akali    {'attack': 5, 'defense': 3, 'magic': 8, 'diffi...
# Akshan   {'attack': 0, 'defense': 0, 'magic': 0, 'diffi...
# Alistar  {'attack': 6, 'defense': 9, 'magic': 5, 'diffi...
# ...                                                    ...
# Zeri     {'attack': 8, 'defense': 5, 'magic': 3, 'diffi...
# Ziggs    {'attack': 2, 'defense': 4, 'magic': 9, 'diffi...
# Zilean   {'attack': 2, 'defense': 5, 'magic': 8, 'diffi...
# Zoe      {'attack': 1, 'defense': 7, 'magic': 8, 'diffi...
# Zyra     {'attack': 4, 'defense': 3, 'magic': 8, 'diffi...
#
#                                                      image  \
# Aatrox   {'full': 'Aatrox.png', 'sprite': 'champion0.pn...
# Ahri     {'full': 'Ahri.png', 'sprite': 'champion0.png'...
# Akali    {'full': 'Akali.png', 'sprite': 'champion0.png...
# Akshan   {'full': 'Akshan.png', 'sprite': 'champion0.pn...
# Alistar  {'full': 'Alistar.png', 'sprite': 'champion0.p...
# ...                                                    ...
# Zeri     {'full': 'Zeri.png', 'sprite': 'champion5.png'...
# Ziggs    {'full': 'Ziggs.png', 'sprite': 'champion5.png...
# Zilean   {'full': 'Zilean.png', 'sprite': 'champion5.pn...
# Zoe      {'full': 'Zoe.png', 'sprite': 'champion5.png',...
# Zyra     {'full': 'Zyra.png', 'sprite': 'champion5.png'...
#
#                          tags     partype  \
# Aatrox        [Fighter, Tank]  Blood Well
# Ahri         [Mage, Assassin]        Mana
# Akali              [Assassin]      Energy
# Akshan   [Marksman, Assassin]        Mana
# Alistar       [Tank, Support]        Mana
# ...                       ...         ...
# Zeri               [Marksman]        Mana
# Ziggs                  [Mage]        Mana
# Zilean        [Support, Mage]        Mana
# Zoe           [Mage, Support]        Mana
# Zyra          [Mage, Support]        Mana
#
#                                                      stats
# Aatrox   {'hp': 650, 'hpperlevel': 104, 'mp': 0, 'mpper...
# Ahri     {'hp': 570, 'hpperlevel': 96, 'mp': 418, 'mppe...
# Akali    {'hp': 570, 'hpperlevel': 119, 'mp': 200, 'mpp...
# Akshan   {'hp': 630, 'hpperlevel': 104, 'mp': 350, 'mpp...
# Alistar  {'hp': 670, 'hpperlevel': 120, 'mp': 350, 'mpp...
# ...                                                    ...
# Zeri     {'hp': 600, 'hpperlevel': 109, 'mp': 250, 'mpp...
# Ziggs    {'hp': 606, 'hpperlevel': 106, 'mp': 480, 'mpp...
# Zilean   {'hp': 574, 'hpperlevel': 96, 'mp': 452, 'mppe...
# Zoe      {'hp': 630, 'hpperlevel': 106, 'mp': 425, 'mpp...
# Zyra     {'hp': 574, 'hpperlevel': 93, 'mp': 418, 'mppe...
#
# [160 rows x 11 columns]

# %%
df.sort_values("key" , ascending=True,inplace=True)
df
# Out:
#              version           id  key          name  \
# Annie        12.12.1        Annie    1         Annie
# Olaf         12.12.1         Olaf    2          Olaf
# Galio        12.12.1        Galio    3         Galio
# TwistedFate  12.12.1  TwistedFate    4  Twisted Fate
# XinZhao      12.12.1      XinZhao    5      Xin Zhao
# ...              ...          ...  ...           ...
# Yone         12.12.1         Yone  777          Yone
# Sett         12.12.1         Sett  875          Sett
# Lillia       12.12.1       Lillia  876        Lillia
# Gwen         12.12.1         Gwen  887          Gwen
# Renata       12.12.1       Renata  888  Renata Glasc
#
#                                 title  \
# Annie                  the Dark Child
# Olaf                    the Berserker
# Galio                    the Colossus
# TwistedFate           the Card Master
# XinZhao      the Seneschal of Demacia
# ...                               ...
# Yone                  the Unforgotten
# Sett                         the Boss
# Lillia              the Bashful Bloom
# Gwen          The Hallowed Seamstress
# Renata              the Chem-Baroness
#
#                                                          blurb  \
# Annie        Dangerous, yet disarmingly precocious, Annie i...
# Olaf         An unstoppable force of destruction, the axe-w...
# Galio        Outside the gleaming city of Demacia, the ston...
# TwistedFate  Twisted Fate is an infamous cardsharp and swin...
# XinZhao      Xin Zhao is a resolute warrior loyal to the ru...
# ...                                                        ...
# Yone         In life, he was Yone—half-brother of Yasuo, an...
# Sett         A leader of Ionia's growing criminal underworl...
# Lillia       Intensely shy, the fae fawn Lillia skittishly ...
# Gwen         A former doll transformed and brought to life ...
# Renata       Renata Glasc rose from the ashes of her childh...
#
#                                                           info  \
# Annie        {'attack': 2, 'defense': 3, 'magic': 10, 'diff...
# Olaf         {'attack': 9, 'defense': 5, 'magic': 3, 'diffi...
# Galio        {'attack': 1, 'defense': 10, 'magic': 6, 'diff...
# TwistedFate  {'attack': 6, 'defense': 2, 'magic': 6, 'diffi...
# XinZhao      {'attack': 8, 'defense': 6, 'magic': 3, 'diffi...
# ...                                                        ...
# Yone         {'attack': 8, 'defense': 4, 'magic': 4, 'diffi...
# Sett         {'attack': 8, 'defense': 5, 'magic': 1, 'diffi...
# Lillia       {'attack': 0, 'defense': 2, 'magic': 10, 'diff...
# Gwen         {'attack': 7, 'defense': 4, 'magic': 5, 'diffi...
# Renata       {'attack': 2, 'defense': 6, 'magic': 9, 'diffi...
#
#                                                          image  \
# Annie        {'full': 'Annie.png', 'sprite': 'champion0.png...
# Olaf         {'full': 'Olaf.png', 'sprite': 'champion2.png'...
# Galio        {'full': 'Galio.png', 'sprite': 'champion1.png...
# TwistedFate  {'full': 'TwistedFate.png', 'sprite': 'champio...
# XinZhao      {'full': 'XinZhao.png', 'sprite': 'champion4.p...
# ...                                                        ...
# Yone         {'full': 'Yone.png', 'sprite': 'champion5.png'...
# Sett         {'full': 'Sett.png', 'sprite': 'champion3.png'...
# Lillia       {'full': 'Lillia.png', 'sprite': 'champion2.pn...
# Gwen         {'full': 'Gwen.png', 'sprite': 'champion1.png'...
# Renata       {'full': 'Renata.png', 'sprite': 'champion3.pn...
#
#                             tags partype  \
# Annie                     [Mage]    Mana
# Olaf             [Fighter, Tank]    Mana
# Galio               [Tank, Mage]    Mana
# TwistedFate               [Mage]    Mana
# XinZhao      [Fighter, Assassin]    Mana
# ...                          ...     ...
# Yone         [Assassin, Fighter]    Flow
# Sett             [Fighter, Tank]    Grit
# Lillia           [Fighter, Mage]    Mana
# Gwen         [Fighter, Assassin]    Mana
# Renata           [Support, Mage]    Mana
#
#                                                          stats
# Annie        {'hp': 594, 'hpperlevel': 102, 'mp': 418, 'mpp...
# Olaf         {'hp': 645, 'hpperlevel': 119, 'mp': 316, 'mpp...
# Galio        {'hp': 632, 'hpperlevel': 126, 'mp': 500, 'mpp...
# TwistedFate  {'hp': 604, 'hpperlevel': 108, 'mp': 333, 'mpp...
# XinZhao      {'hp': 640, 'hpperlevel': 106, 'mp': 274, 'mpp...
# ...                                                        ...
# Yone         {'hp': 620, 'hpperlevel': 99, 'mp': 500, 'mppe...
# Sett         {'hp': 670, 'hpperlevel': 114, 'mp': 0, 'mpper...
# Lillia       {'hp': 625, 'hpperlevel': 104, 'mp': 410, 'mpp...
# Gwen         {'hp': 660, 'hpperlevel': 109, 'mp': 330, 'mpp...
# Renata       {'hp': 595, 'hpperlevel': 94, 'mp': 350, 'mppe...
#
# [160 rows x 11 columns]

# %%
df_champion = df[['name', 'key']]
df_champion['id'] = 0
df_champion
# Out:
# /var/folders/9r/4qn8djgj1_g7m5m_fylb0s7w0000gn/T/ipykernel_10506/4043230280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_champion['id'] = 0
#                      name  key  id
# Annie               Annie    1   0
# Olaf                 Olaf    2   0
# Galio               Galio    3   0
# TwistedFate  Twisted Fate    4   0
# XinZhao          Xin Zhao    5   0
# ...                   ...  ...  ..
# Yone                 Yone  777   0
# Sett                 Sett  875   0
# Lillia             Lillia  876   0
# Gwen                 Gwen  887   0
# Renata       Renata Glasc  888   0
#
# [160 rows x 3 columns]

# %%
df_champion2 = df_champion.copy()
df_champion2['id'] = 0
df_champion2
# Out:
#                      name  key  id
# Annie               Annie    1   0
# Olaf                 Olaf    2   0
# Galio               Galio    3   0
# TwistedFate  Twisted Fate    4   0
# XinZhao          Xin Zhao    5   0
# ...                   ...  ...  ..
# Yone                 Yone  777   0
# Sett                 Sett  875   0
# Lillia             Lillia  876   0
# Gwen                 Gwen  887   0
# Renata       Renata Glasc  888   0
#
# [160 rows x 3 columns]

# %%
combo = df_champion.merge(df_champion2, on='id', how='outer')

combo
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9r/4qn8djgj1_g7m5m_fylb0s7w0000gn/T/ipykernel_10506/2765263004.py in <module>
#       1 combo = df_champion.merge(df_champion2, on='id', how='outer')
# ----> 2 combo.columns = ['champion1','id1','champion2','id2']
#       3 combo
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
#     770         self._clear_item_cache()
#     771
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     212     def set_axis(self, axis: int, new_labels: Index) -> None:
#     213         # Caller is responsible for ensuring we have an Index object.
# --> 214         self._validate_set_axis(axis, new_labels)
#     215         self.axes[axis] = new_labels
#     216
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      67
#      68         elif new_len != old_len:
# ---> 69             raise ValueError(
#      70                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      71                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 5 elements, new values have 4 elements

# %%
combo = combo.loc[combo['key_y'] > combo['key_x']]
combo
# Out:
#        name_x  key_x  id        name_y  key_y
# 1       Annie      1   0          Olaf      2
# 2       Annie      1   0         Galio      3
# 3       Annie      1   0  Twisted Fate      4
# 4       Annie      1   0      Xin Zhao      5
# 5       Annie      1   0         Urgot      6
# ...       ...    ...  ..           ...    ...
# 25118    Sett    875   0          Gwen    887
# 25119    Sett    875   0  Renata Glasc    888
# 25278  Lillia    876   0          Gwen    887
# 25279  Lillia    876   0  Renata Glasc    888
# 25439    Gwen    887   0  Renata Glasc    888
#
# [12720 rows x 5 columns]

# %%
combo.drop(['id'], axis=1,inplace=True)
combo.columns = ['champion1','id1','champion2','id2']
combo['combo'] = 0
combo
# Out:
#           champion1  id1     champion2  id2
# 0             Annie    1         Annie    1
# 1             Annie    1          Olaf    2
# 2             Annie    1         Galio    3
# 3             Annie    1  Twisted Fate    4
# 4             Annie    1      Xin Zhao    5
# ...             ...  ...           ...  ...
# 25595  Renata Glasc  888          Yone  777
# 25596  Renata Glasc  888          Sett  875
# 25597  Renata Glasc  888        Lillia  876
# 25598  Renata Glasc  888          Gwen  887
# 25599  Renata Glasc  888  Renata Glasc  888
#
# [25600 rows x 4 columns]
